# %% [markdown]
# ### Exámen Final - Mortalidad Materna
#
# #### Introducción
# La base de datos contiene información de los casos de defunción relacionados con la mortalidad materna, esta información es pública.

# %%
# Importación de librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Lectura de datos del archivo mortalidad.csv

Mort = pd.read_csv('mortalidad.csv')

# %%
# Impresión de los datos en forma ruda

print(Mort)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
# Impresión de los datos con DataFrame

pd.DataFrame(Mort)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
# Impresión de las primeras 5 filas

Mort.head()
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
# 3               1966                  1                             ENERO
# 4               1975                  0                   NO ESPECIFICADO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
# 3                 23       2                A             36                5
# 4                  0       2                A             30                5
#
# ...

# %% [markdown]
# ### Nombre de los encabezados

# %%
# Impresión de los encabezados de la base de datos con DataFrame

Enca=list(Mort.columns.values)
pd.DataFrame(Enca)
# Out:
#                                                    0
# 0                                  Año de nacimiento
# 1                                  Mes de nacimiento
# 2                  Descripción del mes de nacimiento
# 3                                  Día de nacimiento
# 4                                             Genero
# 5                                   Clave de la edad
# 6                                      Edad cumplida
# 7                                    Estado conyugal
# 8                    Descripción del estado conyugal
# 9                              Entidad de residencia
# 10              Descripción de entidad de residencia
# 11                           Municipio de residencia
# 12           Descripción del municipio de residencia
# 13                           Localidad de residencia
# 14          Descripión de la localidad de residencia
# 15                               Tamaño de localidad
# 16               Descripción del tamaño de localidad
# ...

# %% [markdown]
# ### Muestra un DataFrame que contenga: Edad cumplida, Descripción del estado conyugal, Tamaño de localidad, Localidad de ocurrencia, Descrición de la localidad de ocurrencia

# %%
# Nuevo DataFrame con la información solicitada e impresión de las primeras 5 filas

Mort2 = Mort[['Edad cumplida','Descripción del estado conyugal','Tamaño de localidad','Localidad de ocurrencia','Descrición de la localidad de ocurrencia']]

Mort2.head()
# Out:
#    Edad cumplida Descripción del estado conyugal  Tamaño de localidad  \
# 0             29                          CASADO                    9
# 1             35                          CASADO                    9
# 2             29                          CASADO                    4
# 3             36                          CASADO                    1
# 4             30                          CASADO                    0
#
#    Localidad de ocurrencia Descrición de la localidad de ocurrencia
# 0                        1                     311020001 Valladolid
# 1                        1                         310500001 Mérida
# 2                        1                      310560001 Oxkutzcab
# 3                        1                         310500001 Mérida
# 4                        0                090160000 No especificado

# %% [markdown]
# ### ¿Cuántas edades diferentes tenían las madres cuando fallecieron? Obten los estadísticos para esta columna y los valores de las edades diferentes.

# %%
# Número de edades diferentes que tenían las madres cuando murieron que existen en la base de datos

Difedad=len(Mort['Edad cumplida'].unique())

print('Existen '+str(Difedad)+' edades diferentes en la base de datos.')
# Out:
# Existen 50 edades diferentes en la base de datos.

# %%
# Estadísticos básicos de la columna Edad cumplida

pd.DataFrame(Mort['Edad cumplida'].describe())
# Out:
#        Edad cumplida
# count   17232.000000
# mean       29.765727
# std        36.916010
# min        11.000000
# 25%        22.000000
# 50%        28.000000
# 75%        34.000000
# max       998.000000

# %%
# Lista de edades diferentes que existen en la base de datos impresos en DataFrame

pd.DataFrame(Mort['Edad cumplida'].unique())
# Out:
#       0
# 0    29
# 1    35
# 2    36
# 3    30
# 4    20
# 5    27
# 6    43
# 7    31
# 8    39
# 9    45
# 10   42
# 11   17
# 12   38
# 13   26
# 14   21
# 15   22
# 16   40
# 17   44
# 18   34
# 19   41
# 20   33
# 21   13
# 22   24
# 23   25
# 24   37
# 25   19
# 26   23
# 27   32
# 28   28
# 29  998
# 30   15
# 31   46
# 32   48
# 33   16
# 34   18
# 35   12
# 36   47
# 37   14
# 38   51
# 39   50
# 40   54
# 41   49
# 42   11
# 43   53
# 44   81
# 45   70
# 46   82
# 47   59
# 48   86
# 49   65

# %% [markdown]
# ### Imprime los valores de los años de defunción ¿ Existen datos que son lógicos, es decir, están correctos?

# %%
# Lista de edades diferentes que existen en la base de datos impresos en DataFrame

ListEda=pd.DataFrame(Mort['Año de la defunción'].unique())

pd.DataFrame(ListEda)
# Out:
#        0
# 0   2002
# 1   2005
# 2   2003
# 3   2008
# 4   2013
# 5   2012
# 6   2009
# 7   2010
# 8   2011
# 9   2004
# 10  2006
# 11  2007
# 12  2001
# 13  1979
# 14  1989
# 15  1974
# 16  1964
# 17  1982
# 18  1959
# 19  1990
# 20  1980
# 21  1994
# 22  1977
# 23  1976
# 24  1938
# 25  1970
# 26  1949
# 27  1997
# 28  1956
# 29  1961
# ..   ...
# 39  1993
# 40  1992
# 41  1972
# 42  1973
# 43  1986
# 44  1988
# 45  1937
# 46  1965
# 47  1944
# 48  1987
# 49  1943
# 50  1958
# 51  1967
# 52  1968
# 53  1995
# 54  1991
# 55  1969
# 56  1999
# 57  1966
# 58  1963
# 59  1953
# 60  1954
# 61  1962
# 62  1950
# 63  1996
# 64  2014
# 65  2015
# 66  1914
# 67  1951
# 68  2016
#
# [69 rows x 1 columns]

# %%
# Imprimo los primeros 35 registros para analizarlos

ListEda.head(35)
# Out:
#        0
# 0   2002
# 1   2005
# 2   2003
# 3   2008
# 4   2013
# 5   2012
# 6   2009
# 7   2010
# 8   2011
# 9   2004
# 10  2006
# 11  2007
# 12  2001
# 13  1979
# 14  1989
# 15  1974
# 16  1964
# 17  1982
# 18  1959
# 19  1990
# 20  1980
# 21  1994
# 22  1977
# 23  1976
# 24  1938
# 25  1970
# 26  1949
# 27  1997
# 28  1956
# 29  1961
# 30  1957
# 31  1985
# 32  1975
# 33  2000
# 34     0

# %%
# Imprimo los últimos 34 registros para analizarlos
ListEda.tail(34)
# Out:
#        0
# 35  1948
# 36  1971
# 37  1978
# 38  1984
# 39  1993
# 40  1992
# 41  1972
# 42  1973
# 43  1986
# 44  1988
# 45  1937
# 46  1965
# 47  1944
# 48  1987
# 49  1943
# 50  1958
# 51  1967
# 52  1968
# 53  1995
# 54  1991
# 55  1969
# 56  1999
# 57  1966
# 58  1963
# 59  1953
# 60  1954
# 61  1962
# 62  1950
# 63  1996
# 64  2014
# 65  2015
# 66  1914
# 67  1951
# 68  2016

# %% [markdown]
# #### No, no todos los datos son correctos pues tenemos un registro con valor 0 en nuestra información. Estamos analizando los años de defunción por lo cuál esperamos un año como valor.

# %% [markdown]
# ### ¿Cuántos tipos de escolaridad existen? ¿Hay datos innecesarios o equivocados en la base de datos?

# %%
#Número de tipos de escolaridad que existen en la base de datos

Esco=len(Mort['Descripción de la escolaridad'].unique())
print('Existen '+str(Esco)+' tipos de escolaridad diferentes en la base de datos.')
# Out:
# Existen 12 tipos de escolaridad diferentes en la base de datos.

# %%
# Lista de tipos de escolaridad que existen en la base de datos impresos en DataFrame

pd.DataFrame(Mort['Descripción de la escolaridad'].unique())
# Out:
#                                          0
# 0                      PRIMARIA INCOMPLETA
# 1                    SECUNDARIA INCOMPLETA
# 2                              PROFESIONAL
# 3                                  NINGUNA
# 4                      SECUNDARIA COMPLETA
# 5                          NO ESPECIFICADO
# 6                                 POSGRADO
# 7                        PRIMARIA COMPLETA
# 8     BACHILLERATO O PREPARATORIA COMPLETA
# 9   BACHILLERATO O PREPARATORIA INCOMPLETA
# 10                     NO ESPECIFICADO\r\n
# 11                              PREESCOLAR

# %% [markdown]
# #### Si, si hay datos innecesarios en la base de datos; el dato NO ESPECIFICADO\r\n

# %% [markdown]
# ### ¿Qué entidad tiene mayor número muertes?

# %%
# Lista de entidades de ocurrencia que existen en la base de datos impresos en DataFrame

pd.DataFrame(Mort['Descripción de la entidad de ocurrencia'].unique())
# Out:
#                                   0
# 0                           Yucatán
# 1                  Distrito Federal
# 2                            México
# 3                         Zacatecas
# 4               Baja California Sur
# 5                        Guanajuato
# 6               Michoacán de Ocampo
# 7   Veracruz de Ignacio de la Llave
# 8                           Tabasco
# 9                        Tamaulipas
# 10                          Chiapas
# 11                          Nayarit
# 12                         Guerrero
# 13                           Puebla
# 14                     Quintana Roo
# 15                           Oaxaca
# 16                           Sonora
# 17                Querétaro Arteaga
# 18                       Nuevo León
# 19                          Sinaloa
# 20                        Chihuahua
# 21                  San Luis Potosí
# 22                          Hidalgo
# 23                          Durango
# 24                          Morelos
# ...
